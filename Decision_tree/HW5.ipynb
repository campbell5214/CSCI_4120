# %% [markdown]
# # Homework 5 RF Accuracy Improvement
#
# This assignment is inspired by examples of Shan-Hung Wu from National Tsing Hua University.
#
# Requirement: improve the accuracy per feature of the following code from 0.03 up to at least 0.45 and accuracy should be more than 0.92
#
# Here are three hints:
#
#     You can improve the ratio by picking out or "creating" several features.
#     Tune hyperparameters
#     The ratio can be improved from 0.03 up to 0.47.

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()
X, y = data.data, data.target

print("Initial shape of data:", X.shape)

# TODO Select some features (X), hint: based on the connections with
# our Y (importance? correlation?)
clf = RandomForestClassifier(n_estimators=100)
rfe = RFE(estimator=clf, n_features_to_select=2)
X_selected = rfe.fit_transform(X, y)

print("Shape of selected data:", X_selected.shape)

cv_scores = cross_val_score(clf, X_selected, y, cv=5)
avg_accuracy = np.mean(cv_scores)

clf_tuned = RandomForestClassifier(
    n_estimators=1000,
    max_depth=20,
    min_samples_split=2,
    min_samples_leaf=1,
    criterion='entropy',
    max_features='sqrt'
)

cv_scores_tuned = cross_val_score(clf_tuned, X_selected, y, cv=5)
avg_accuracy_tuned = np.mean(cv_scores_tuned)

accuracy_per_feature = avg_accuracy_tuned / X_selected.shape[1]

print(f"Average accuracy with selected features: {avg_accuracy:.4f}")
print(f"Average accuracy with tuned parameters: {avg_accuracy_tuned:.4f}")
print(f"Accuracy per feature: {accuracy_per_feature:.4f}")
# Out:
# Initial shape of data: (569, 30)
# Shape of selected data: (569, 2)
# Average accuracy with selected features: 0.9016
# Average accuracy with tuned parameters: 0.8981
# Accuracy per feature: 0.4490
